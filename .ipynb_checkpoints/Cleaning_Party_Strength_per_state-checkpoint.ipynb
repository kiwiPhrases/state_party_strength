# %% [markdown]
# # Clean the data into a usable format
# There are presently a few issues with the data. First, names are not much use in the analysis that we plan to do therefore, all information beside the number of republicans or democrats in each chamber will be removed. Once removed, I will tally up the number of each party members in each chamber where necessary and separate the columns into usable formats.

# %%
import pandas as pd
import numpy as np
import re, os

data_path = "C:/Users/SpiffyApple/Documents/USC/RaphaelBostic/policy_diffusion"

# %%
df = pd.read_csv("/".join([data_path, "states_party_strength.csv"]), encoding = "ISO-8859-1")
df.head()
# Out:
#   Unnamed: 0  year congress house congress sen class 1 congress sen class 2  \
# 0    Alabama  1980         4D, 3R                  NaN    Howell Heflin (D)
# 1    Alabama  1981         4D, 3R                  NaN    Howell Heflin (D)
# 2    Alabama  1982         4D, 3R                  NaN    Howell Heflin (D)
# 3    Alabama  1983         5D, 2R                  NaN    Howell Heflin (D)
# 4    Alabama  1984         5D, 2R                  NaN    Howell Heflin (D)
#
#     congress sen class 3                                  electoral  \
# 0  Donald W. Stewart (D)  Ronald Reagan and George H. W. Bush (R) Y
# 1    Jeremiah Denton (R)  Ronald Reagan and George H. W. Bush (R) Y
# 2    Jeremiah Denton (R)  Ronald Reagan and George H. W. Bush (R) Y
# 3    Jeremiah Denton (R)  Ronald Reagan and George H. W. Bush (R) Y
# 4    Jeremiah Denton (R)  Ronald Reagan and George H. W. Bush (R) Y
#
#              governor legislature house legislature sen
# 0       Fob James (D)          101D, 4R             35D
# 1       Fob James (D)          101D, 4R             35D
# 2       Fob James (D)          101D, 4R             35D
# 3  George Wallace (D)           97D, 8R         32D, 3R
# 4  George Wallace (D)          87D, 18R     29D, 3R, 3I

# %%
df.rename(columns = {"Unnamed: 0":'state'}, inplace=True)

# %%
## set the data index for convenience and efficiency
mlt_idx = pd.MultiIndex.from_arrays([df.state.str.lower(), df.year])
df.set_index(mlt_idx, inplace=True)
df.sort_index(inplace=True)
df.drop(['state', 'year'], inplace=True, axis=1)

# %%
df.head()
# Out:
#              congress house congress sen class 1 congress sen class 2  \
# state   year
# alabama 1980         4D, 3R                  NaN    Howell Heflin (D)
#         1981         4D, 3R                  NaN    Howell Heflin (D)
#         1982         4D, 3R                  NaN    Howell Heflin (D)
#         1983         5D, 2R                  NaN    Howell Heflin (D)
#         1984         5D, 2R                  NaN    Howell Heflin (D)
#
#                congress sen class 3  \
# state   year
# alabama 1980  Donald W. Stewart (D)
#         1981    Jeremiah Denton (R)
#         1982    Jeremiah Denton (R)
#         1983    Jeremiah Denton (R)
#         1984    Jeremiah Denton (R)
#
#                                               electoral            governor  \
# state   year
# alabama 1980  Ronald Reagan and George H. W. Bush (R) Y       Fob James (D)
#         1981  Ronald Reagan and George H. W. Bush (R) Y       Fob James (D)
#         1982  Ronald Reagan and George H. W. Bush (R) Y       Fob James (D)
#         1983  Ronald Reagan and George H. W. Bush (R) Y  George Wallace (D)
#         1984  Ronald Reagan and George H. W. Bush (R) Y  George Wallace (D)
#
#              legislature house legislature sen
# state   year
# alabama 1980          101D, 4R             35D
#         1981          101D, 4R             35D
#         1982          101D, 4R             35D
#         1983           97D, 8R         32D, 3R
#         1984          87D, 18R     29D, 3R, 3I

# %%
#functions to count the number of parties.
def party_counter(s, party = 'D'):
    ## count the number of each party
    if type(s) is str:
        num_found = len(re.findall(party, s.strip()))
        return(str(num_found)+party)
    else:
        return(s)
    
def party_finder(s):
    ## find the number of parties in the string
    if type(s) is str:
        p_types = set(re.findall("\w", s))
        return(p_types)
    else:
        return(s)

def remove_citations(s):
    if type(s) is str:
        return(re.sub("\[\d+\]","",s))
    else:
        return(s)
    
def name_remover(s):
    ## find a eliminate names
    if type(s) is str:
        s = remove_citations(s)
        if re.search("[\w]{2,}",s):
            match = re.findall("\((\w)\)", s)
            if match:
                return(",".join(match))
            else:
                return(s)
        else:
            return(s)  
    else:
        return(s)
    
def parties_counter(s):
    ## combine the above two functions into one that determines party types then counts occurences
    ## NOTE: this does not check for presence of names. Thus, "John Dill (R)" will end up being a hefty num of parties.
    if type(s) is str:
        s = remove_citations(s)
        if len(re.findall('\d+', s)) == 0: ##eliminates already counted cases
           
            s = name_remover(s)
            p_types = party_finder(s)
            p_counts = []
            for party_type in p_types:
                p_counts.append(party_counter(s, party_type))
            return(",".join(p_counts))
        else:
            return(s)
    else:
        return(s)

def party_count_parser(s, party='D'):
    ## enable to numerically interpret the data. ie 10D,5R isn't conducive to analysis while 10 or 5 is. 
    return(s)

# %%
## fix the column house congress to contain only counts
df['congress house'] = df['congress house'].apply(parties_counter)

# %%
## now, I want to apply the name remover function to the non-house fields. 
for col in df.columns[df.columns.str.contains("electoral|sen|governor")]:
    df.loc[:,col] = df.loc[:,col].apply(name_remover)

# %%
## now I want to combine the senatorial columns and do the party count, hence:

df['congress sen'] = df[['congress sen class 1','congress sen class 2','congress sen class 3']].fillna('').apply(lambda s: ",".join(s), axis=1)
df['congress sen'] = df['congress sen'].apply(parties_counter)

# %%
## one last item before the data are useable
df['legislature house'] = df['legislature house'].apply(remove_citations)

# %%
df.head()
# Out:
#              congress house congress sen class 1 congress sen class 2  \
# state   year
# alabama 1980         4D, 3R                  NaN                    D
#         1981         4D, 3R                  NaN                    D
#         1982         4D, 3R                  NaN                    D
#         1983         5D, 2R                  NaN                    D
#         1984         5D, 2R                  NaN                    D
#
#              congress sen class 3 electoral governor legislature house  \
# state   year
# alabama 1980                    D         R        D          101D, 4R
#         1981                    R         R        D          101D, 4R
#         1982                    R         R        D          101D, 4R
#         1983                    R         R        D           97D, 8R
#         1984                    R         R        D          87D, 18R
#
#              legislature sen congress sen
# state   year
# alabama 1980             35D           2D
#         1981             35D        1D,1R
#         1982             35D        1D,1R
#         1983         32D, 3R        1D,1R
#         1984     29D, 3R, 3I        1D,1R

# %%
df.to_csv("/".join([data_path,"states_party_strength_cleaned.csv"]), encoding = "‘utf-8’")
